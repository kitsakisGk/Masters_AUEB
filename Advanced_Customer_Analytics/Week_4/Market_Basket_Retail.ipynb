# %% [markdown]
# ## Market Basket Analysis (Retail)

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.23.4-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from mlxtend) (1.16.3)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.12/dist-packages (from mlxtend) (2.0.2)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.12/dist-packages (from mlxtend) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from mlxtend) (1.6.1)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from mlxtend) (3.10.0)
# Requirement already satisfied: joblib>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->mlxtend) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->mlxtend) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->mlxtend) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->mlxtend) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# Downloading mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 25.4 MB/s eta 0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.4

# %%
data = pd.read_excel('/content/sample_data/Online Retail.xlsx',engine='openpyxl')

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)

# %%
data.shape # get the shape of the data
# Out:
# (541909, 8)

# %%
data.head(200) # get the first few transactions in the file
# Out:
#     InvoiceNo StockCode                          Description  Quantity  \
# 0      536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      536365     71053                  WHITE METAL LANTERN         6
# 2      536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3      536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ..        ...       ...                                  ...       ...
# 195    536388     22469                HEART OF WICKER SMALL        12
# 196    536388     22242        5 HOOK HANGER MAGIC TOADSTOOL        12
# 197    536389     22941         CHRISTMAS LIGHTS 10 REINDEER         6
# 198    536389     21622     VINTAGE UNION JACK CUSHION COVER         8
# 199    536389     21791   VINTAGE HEADS AND TAILS CARD GAME         12
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0   2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1   2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2   2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3   2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4   2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ..                  ...        ...         ...             ...
# 195 2010-12-01 09:59:00       1.65     16250.0  United Kingdom
# 196 2010-12-01 09:59:00       1.65     16250.0  United Kingdom
# 197 2010-12-01 10:03:00       8.50     12431.0       Australia
# 198 2010-12-01 10:03:00       4.95     12431.0       Australia
# 199 2010-12-01 10:03:00       1.25     12431.0       Australia
#
# [200 rows x 8 columns]

# %%
# Clean up spaces in description and remove any rows that don't have a valid invoice
data['Description'] = data['Description'].str.strip()

data.dropna(axis=0, subset=['InvoiceNo'], inplace=True) # remove transactions without an invoice

# %%
#remove credit transactions
data['InvoiceNo'] = data['InvoiceNo'].astype('str') # convert the column into a string format
data = data[~data['InvoiceNo'].str.contains('C')] # remove rows that have a 'C' in the InvoiceNo

# %%
france_data=data[data['Country'] =="France"] # focus on transactions from france.
france_data.shape
# Out:
# (8408, 8)

# %%
# organize the data by invoice and description
france_grouping=france_data.groupby(['InvoiceNo', 'Description'])['Quantity'].sum()
france_grouping
# Out:
# InvoiceNo  Description
# 536370     ALARM CLOCK BAKELIKE GREEN         12
#            ALARM CLOCK BAKELIKE PINK          24
#            ALARM CLOCK BAKELIKE RED           24
#            CHARLOTTE BAG DOLLY GIRL DESIGN    20
#            CIRCUS PARADE LUNCH BOX            24
#                                               ..
# 581587     CIRCUS PARADE LUNCH BOX            12
#            PACK OF 20 SPACEBOY NAPKINS        12
#            PLASTERS IN TIN CIRCUS PARADE      12
#            PLASTERS IN TIN STRONGMAN          12
#            SPACEBOY LUNCH BOX                 12
# Name: Quantity, Length: 8372, dtype: int64

# %%
france_matrix=france_grouping.unstack() #expand the grouping into a matrix
france_matrix
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                          NaN                         NaN
# 536852                          NaN                         NaN
# 536974                          NaN                         NaN
# 537065                          NaN                         NaN
# 537463                          NaN                         NaN
# ...                             ...                         ...
# 580986                          NaN                         NaN
# 581001                          NaN                         NaN
# 581171                          NaN                         NaN
# 581279                          NaN                         NaN
# 581587                          NaN                         NaN
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                             NaN                              NaN
# 536852                             NaN                              NaN
# 536974                             NaN                              NaN
# 537065                             NaN                              NaN
# 537463                             NaN                              NaN
# ...                                ...                              ...
# 580986                             NaN                              NaN
# 581001                             NaN                              NaN
# 581171                             NaN                              NaN
# 581279                             NaN                              NaN
# 581587                             NaN                              NaN
#
# Description  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536370                                 NaN
# 536852                                 NaN
# 536974                                 NaN
# 537065                                 NaN
# 537463                                 NaN
# ...                                    ...
# 580986                                 NaN
# 581001                                 NaN
# 581171                                 NaN
# 581279                                 NaN
# 581587                                 NaN
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS SMALL TUBE SKULL  \
# InvoiceNo
# 536370                                       NaN                          NaN
# 536852                                       NaN                          NaN
# 536974                                       NaN                          NaN
# 537065                                       NaN                          NaN
# 537463                                       NaN                          NaN
# ...                                          ...                          ...
# 580986                                       NaN                          NaN
# 581001                                       NaN                          NaN
# 581171                                       NaN                          NaN
# 581279                                       NaN                          NaN
# 581587                                       NaN                          NaN
#
# Description  12 PENCILS TALL TUBE POSY  12 PENCILS TALL TUBE RED RETROSPOT  \
# InvoiceNo
# 536370                             NaN                                 NaN
# 536852                             NaN                                 NaN
# 536974                             NaN                                 NaN
# 537065                             NaN                                 NaN
# 537463                             NaN                                 NaN
# ...                                ...                                 ...
# 580986                             NaN                                 NaN
# 581001                             NaN                                 NaN
# 581171                             NaN                                 NaN
# 581279                             NaN                                 NaN
# 581587                             NaN                                 NaN
#
# Description  12 PENCILS TALL TUBE WOODLAND  ...  WRAP VINTAGE PETALS  DESIGN  \
# InvoiceNo                                   ...
# 536370                                 NaN  ...                          NaN
# 536852                                 NaN  ...                          NaN
# 536974                                 NaN  ...                          NaN
# 537065                                 NaN  ...                          NaN
# 537463                                 NaN  ...                          NaN
# ...                                    ...  ...                          ...
# 580986                                 NaN  ...                          NaN
# 581001                                 NaN  ...                          NaN
# 581171                                 NaN  ...                          NaN
# 581279                                 NaN  ...                          NaN
# 581587                                 NaN  ...                          NaN
#
# Description  YELLOW COAT RACK PARIS FASHION  YELLOW GIANT GARDEN THERMOMETER  \
# InvoiceNo
# 536370                                  NaN                              NaN
# 536852                                  NaN                              NaN
# 536974                                  NaN                              NaN
# 537065                                  NaN                              NaN
# 537463                                  NaN                              NaN
# ...                                     ...                              ...
# 580986                                  NaN                              NaN
# 581001                                  NaN                              NaN
# 581171                                  NaN                              NaN
# 581279                                  NaN                              NaN
# 581587                                  NaN                              NaN
#
# Description  YELLOW SHARK HELICOPTER  ZINC  STAR T-LIGHT HOLDER  \
# InvoiceNo
# 536370                           NaN                        NaN
# 536852                           NaN                        NaN
# 536974                           NaN                        NaN
# 537065                           NaN                        NaN
# 537463                           NaN                        NaN
# ...                              ...                        ...
# 580986                           NaN                        NaN
# 581001                           NaN                        NaN
# 581171                           NaN                        NaN
# 581279                           NaN                        NaN
# 581587                           NaN                        NaN
#
# Description  ZINC FOLKART SLEIGH BELLS  ZINC HERB GARDEN CONTAINER  \
# InvoiceNo
# 536370                             NaN                         NaN
# 536852                             NaN                         NaN
# 536974                             NaN                         NaN
# 537065                             NaN                         NaN
# 537463                             NaN                         NaN
# ...                                ...                         ...
# 580986                             NaN                         NaN
# 581001                             NaN                         NaN
# 581171                             NaN                         NaN
# 581279                             NaN                         NaN
# 581587                             NaN                         NaN
#
# Description  ZINC METAL HEART DECORATION  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536370                               NaN                             NaN
# 536852                               NaN                             NaN
# 536974                               NaN                             NaN
# 537065                               NaN                             NaN
# 537463                               NaN                             NaN
# ...                                  ...                             ...
# 580986                               NaN                             NaN
# 581001                               NaN                             NaN
# 581171                               NaN                             NaN
# 581279                               NaN                             NaN
# 581587                               NaN                             NaN
#
# Description  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo
# 536370                                   NaN
# 536852                                   NaN
# 536974                                   NaN
# 537065                                   NaN
# 537463                                   NaN
# ...                                      ...
# 580986                                   NaN
# 581001                                   NaN
# 581171                                   NaN
# 581279                                   NaN
# 581587                                   NaN
#
# [392 rows x 1563 columns]

# %%
#convert the matrix into a True/False format: False->not bought, True->bought
france_matrix=france_matrix.notnull()
france_matrix.tail(10)
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 580705                        False                       False
# 580706                        False                       False
# 580736                        False                       False
# 580753                        False                       False
# 580756                        False                       False
# 580986                        False                       False
# 581001                        False                       False
# 581171                        False                       False
# 581279                        False                       False
# 581587                        False                       False
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 580705                           False                            False
# 580706                           False                            False
# 580736                           False                            False
# 580753                           False                            False
# 580756                           False                            False
# 580986                           False                            False
# 581001                           False                            False
# 581171                           False                            False
# 581279                           False                            False
# 581587                           False                            False
#
# Description  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 580705                               False
# 580706                               False
# 580736                               False
# 580753                               False
# 580756                               False
# 580986                               False
# 581001                               False
# 581171                               False
# 581279                               False
# 581587                               False
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS SMALL TUBE SKULL  \
# InvoiceNo
# 580705                                     False                        False
# 580706                                     False                        False
# 580736                                     False                        False
# 580753                                     False                        False
# 580756                                     False                        False
# 580986                                     False                        False
# 581001                                     False                        False
# 581171                                     False                        False
# 581279                                     False                        False
# 581587                                     False                        False
#
# Description  12 PENCILS TALL TUBE POSY  12 PENCILS TALL TUBE RED RETROSPOT  \
# InvoiceNo
# 580705                           False                               False
# 580706                           False                               False
# 580736                           False                               False
# 580753                           False                               False
# 580756                           False                               False
# 580986                           False                               False
# 581001                           False                               False
# 581171                           False                               False
# 581279                           False                               False
# 581587                           False                               False
#
# Description  12 PENCILS TALL TUBE WOODLAND  ...  WRAP VINTAGE PETALS  DESIGN  \
# InvoiceNo                                   ...
# 580705                               False  ...                        False
# 580706                               False  ...                        False
# 580736                               False  ...                        False
# 580753                               False  ...                        False
# 580756                               False  ...                        False
# 580986                               False  ...                        False
# 581001                               False  ...                        False
# 581171                               False  ...                        False
# 581279                               False  ...                        False
# 581587                               False  ...                        False
#
# Description  YELLOW COAT RACK PARIS FASHION  YELLOW GIANT GARDEN THERMOMETER  \
# InvoiceNo
# 580705                                False                            False
# 580706                                False                            False
# 580736                                False                            False
# 580753                                False                            False
# 580756                                False                            False
# 580986                                False                            False
# 581001                                False                            False
# 581171                                False                            False
# 581279                                False                            False
# 581587                                False                            False
#
# Description  YELLOW SHARK HELICOPTER  ZINC  STAR T-LIGHT HOLDER  \
# InvoiceNo
# 580705                         False                      False
# 580706                         False                      False
# 580736                         False                      False
# 580753                         False                      False
# 580756                         False                      False
# 580986                         False                      False
# 581001                         False                      False
# 581171                         False                      False
# 581279                         False                      False
# 581587                         False                      False
#
# Description  ZINC FOLKART SLEIGH BELLS  ZINC HERB GARDEN CONTAINER  \
# InvoiceNo
# 580705                           False                       False
# 580706                           False                       False
# 580736                           False                       False
# 580753                           False                       False
# 580756                           False                       False
# 580986                           False                       False
# 581001                           False                       False
# 581171                           False                       False
# 581279                           False                       False
# 581587                           False                       False
#
# Description  ZINC METAL HEART DECORATION  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 580705                             False                           False
# 580706                             False                           False
# 580736                             False                           False
# 580753                             False                           False
# 580756                             False                           False
# 580986                             False                           False
# 581001                             False                           False
# 581171                             False                           False
# 581279                             False                           False
# 581587                             False                           False
#
# Description  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo
# 580705                                 False
# 580706                                 False
# 580736                                 False
# 580753                                 False
# 580756                                 False
# 580986                                 False
# 581001                                 False
# 581171                                 False
# 581279                                 False
# 581587                                 False
#
# [10 rows x 1563 columns]

# %%
#example column distribution
france_matrix['10 COLOUR SPACEBOY PEN'].value_counts()
# Out:
# 10 COLOUR SPACEBOY PEN
# False    380
# True      12
# Name: count, dtype: int64

# %% [markdown]
# # Finding frequent itemsets

# %%
#Now, let us return the items and itemsets with at least 10% support:
frequent_itemsets=apriori(france_matrix, min_support = 0.1, use_colnames = True)

frequent_itemsets
# Out:
#      support                                           itemsets
# 0   0.102041                        (ALARM CLOCK BAKELIKE PINK)
# 1   0.125000                           (LUNCH BAG APPLE DESIGN)
# 2   0.153061                          (LUNCH BAG RED RETROSPOT)
# 3   0.119898                        (LUNCH BAG SPACEBOY DESIGN)
# 4   0.117347                               (LUNCH BAG WOODLAND)
# 5   0.142857                 (LUNCH BOX WITH CUTLERY RETROSPOT)
# 6   0.104592                           (MINI PAINT SET VINTAGE)
# 7   0.102041                  (PACK OF 72 RETROSPOT CAKE CASES)
# 8   0.168367                    (PLASTERS IN TIN CIRCUS PARADE)
# 9   0.137755                         (PLASTERS IN TIN SPACEBOY)
# 10  0.170918                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 11  0.765306                                          (POSTAGE)
# 12  0.188776                               (RABBIT NIGHT LIGHT)
# 13  0.137755                         (RED RETROSPOT MINI CASES)
# 14  0.181122                    (RED TOADSTOOL LED NIGHT LIGHT)
# 15  0.125000                         (REGENCY CAKESTAND 3 TIER)
# 16  0.107143                (ROUND SNACK BOXES SET OF 4 FRUITS)
# 17  0.158163               (ROUND SNACK BOXES SET OF4 WOODLAND)
# 18  0.132653               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 19  0.137755                      (SET/6 RED SPOTTY PAPER CUPS)
# 20  0.127551                    (SET/6 RED SPOTTY PAPER PLATES)
# 21  0.125000                               (SPACEBOY LUNCH BOX)
# 22  0.122449                (STRAWBERRY LUNCH BOX WITH CUTLERY)
# 23  0.104592                  (POSTAGE, LUNCH BAG APPLE DESIGN)
# 24  0.122449                 (POSTAGE, LUNCH BAG RED RETROSPOT)
# 25  0.102041                      (POSTAGE, LUNCH BAG WOODLAND)
# 26  0.114796        (POSTAGE, LUNCH BOX WITH CUTLERY RETROSPOT)
# 27  0.102041  (PLASTERS IN TIN CIRCUS PARADE, PLASTERS IN TI...
# 28  0.147959           (POSTAGE, PLASTERS IN TIN CIRCUS PARADE)
# 29  0.104592  (PLASTERS IN TIN SPACEBOY, PLASTERS IN TIN WOO...
# 30  0.114796                (POSTAGE, PLASTERS IN TIN SPACEBOY)
# 31  0.137755        (POSTAGE, PLASTERS IN TIN WOODLAND ANIMALS)
# 32  0.165816                      (POSTAGE, RABBIT NIGHT LIGHT)
# 33  0.114796                (POSTAGE, RED RETROSPOT MINI CASES)
# 34  0.158163           (POSTAGE, RED TOADSTOOL LED NIGHT LIGHT)
# 35  0.104592                (POSTAGE, REGENCY CAKESTAND 3 TIER)
# 36  0.147959      (POSTAGE, ROUND SNACK BOXES SET OF4 WOODLAND)
# 37  0.109694      (SET/20 RED RETROSPOT PAPER NAPKINS, POSTAGE)
# 38  0.117347             (POSTAGE, SET/6 RED SPOTTY PAPER CUPS)
# 39  0.107143           (POSTAGE, SET/6 RED SPOTTY PAPER PLATES)
# 40  0.114796       (STRAWBERRY LUNCH BOX WITH CUTLERY, POSTAGE)
# 41  0.102041  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 42  0.102041  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 43  0.122449  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...
# 44  0.102041  (POSTAGE, SET/6 RED SPOTTY PAPER PLATES, SET/6...

# %% [markdown]
# # Finding Rules

# %%
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5,support_only=False,num_itemsets=france_matrix.shape[0])
rules
# Out:
#                                           antecedents  \
# 0                            (LUNCH BAG APPLE DESIGN)
# 1                           (LUNCH BAG RED RETROSPOT)
# 2                                (LUNCH BAG WOODLAND)
# 3                  (LUNCH BOX WITH CUTLERY RETROSPOT)
# 4                     (PLASTERS IN TIN CIRCUS PARADE)
# 5                  (PLASTERS IN TIN WOODLAND ANIMALS)
# 6                     (PLASTERS IN TIN CIRCUS PARADE)
# 7                          (PLASTERS IN TIN SPACEBOY)
# 8                  (PLASTERS IN TIN WOODLAND ANIMALS)
# 9                          (PLASTERS IN TIN SPACEBOY)
# 10                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 11                               (RABBIT NIGHT LIGHT)
# 12                         (RED RETROSPOT MINI CASES)
# 13                    (RED TOADSTOOL LED NIGHT LIGHT)
# 14                         (REGENCY CAKESTAND 3 TIER)
# 15               (ROUND SNACK BOXES SET OF4 WOODLAND)
# 16               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 17                      (SET/6 RED SPOTTY PAPER CUPS)
# 18                    (SET/6 RED SPOTTY PAPER PLATES)
# 19                (STRAWBERRY LUNCH BOX WITH CUTLERY)
# 20               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 21                      (SET/6 RED SPOTTY PAPER CUPS)
# 22               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 23                    (SET/6 RED SPOTTY PAPER PLATES)
# 24                    (SET/6 RED SPOTTY PAPER PLATES)
# 25                      (SET/6 RED SPOTTY PAPER CUPS)
# 26           (POSTAGE, SET/6 RED SPOTTY PAPER PLATES)
# 27             (POSTAGE, SET/6 RED SPOTTY PAPER CUPS)
# 28  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...
# 29                    (SET/6 RED SPOTTY PAPER PLATES)
# 30                      (SET/6 RED SPOTTY PAPER CUPS)
#
#                                  consequents  antecedent support  \
# 0                                  (POSTAGE)            0.125000
# 1                                  (POSTAGE)            0.153061
# 2                                  (POSTAGE)            0.117347
# 3                                  (POSTAGE)            0.142857
# 4         (PLASTERS IN TIN WOODLAND ANIMALS)            0.168367
# 5            (PLASTERS IN TIN CIRCUS PARADE)            0.170918
# 6                                  (POSTAGE)            0.168367
# 7         (PLASTERS IN TIN WOODLAND ANIMALS)            0.137755
# 8                 (PLASTERS IN TIN SPACEBOY)            0.170918
# 9                                  (POSTAGE)            0.137755
# 10                                 (POSTAGE)            0.170918
# 11                                 (POSTAGE)            0.188776
# 12                                 (POSTAGE)            0.137755
# 13                                 (POSTAGE)            0.181122
# 14                                 (POSTAGE)            0.125000
# 15                                 (POSTAGE)            0.158163
# 16                                 (POSTAGE)            0.132653
# 17                                 (POSTAGE)            0.137755
# 18                                 (POSTAGE)            0.127551
# 19                                 (POSTAGE)            0.122449
# 20             (SET/6 RED SPOTTY PAPER CUPS)            0.132653
# 21      (SET/20 RED RETROSPOT PAPER NAPKINS)            0.137755
# 22           (SET/6 RED SPOTTY PAPER PLATES)            0.132653
# 23      (SET/20 RED RETROSPOT PAPER NAPKINS)            0.127551
# 24             (SET/6 RED SPOTTY PAPER CUPS)            0.127551
# 25           (SET/6 RED SPOTTY PAPER PLATES)            0.137755
# 26             (SET/6 RED SPOTTY PAPER CUPS)            0.107143
# 27           (SET/6 RED SPOTTY PAPER PLATES)            0.117347
# 28                                 (POSTAGE)            0.122449
# 29    (POSTAGE, SET/6 RED SPOTTY PAPER CUPS)            0.127551
# 30  (POSTAGE, SET/6 RED SPOTTY PAPER PLATES)            0.137755
#
#     consequent support   support  confidence      lift  representativity  \
# 0             0
# 25  0.104878    7.852041       0.993343  0.857143   0.872645    0.924444
# 26  0.087281   18.107143       0.958000  0.714286   0.944773    0.846561
# 27  0.087073    6.688776       0.966763  0.714286   0.850496    0.834783
# 28  0.008330    1.408163       0.093023  0.129870   0.289855    0.483333
# 29  0.087073    4.413265       0.978070  0.714286   0.773410    0.834783
# 30  0.087281    3.443878       0.992012  0.714286   0.709630    0.846561

# %%
# !pip install --upgrade mlxtend
# Out:
# Requirement already satisfied: mlxtend in /usr/local/lib/python3.12/dist-packages (0.23.4)
# Requirement already satisfied: scipy>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from mlxtend) (1.16.3)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.12/dist-packages (from mlxtend) (2.0.2)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.12/dist-packages (from mlxtend) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from mlxtend) (1.6.1)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from mlxtend) (3.10.0)
# Requirement already satisfied: joblib>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->mlxtend) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->mlxtend) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->mlxtend) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->mlxtend) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)

# %% [markdown]
# # Create a function

# %%
# a function to retrieve association rules for a specific country
def get_rules(full_data, country, minimum_support, minimum_confidence):

    country_data=full_data[data['Country'] == country] # focus on transactions from the given country

    # organize the data by invoice and description
    country_grouping=country_data.groupby(['InvoiceNo', 'Description'])['Quantity'].sum()

    country_matrix=country_grouping.unstack() #expand the grouping into a matrix

    #conver the matrix into a True/False format: False->not bought, True->bought
    country_matrix=country_matrix.notnull()

    #get the frequent itemsets
    country_frequent_itemsets=apriori(country_matrix, min_support = minimum_support, use_colnames = True)

    #get the rules
    country_rules = association_rules(country_frequent_itemsets, metric="confidence", min_threshold=minimum_confidence)

    return country_rules

# %%
france_rules=get_rules(data, 'France', 0.1, 0.5)
france_rules
# Out:
#                                           antecedents  \
# 0                            (LUNCH BAG APPLE DESIGN)
# 1                           (LUNCH BAG RED RETROSPOT)
# 2                                (LUNCH BAG WOODLAND)
# 3                  (LUNCH BOX WITH CUTLERY RETROSPOT)
# 4                     (PLASTERS IN TIN CIRCUS PARADE)
# 5                  (PLASTERS IN TIN WOODLAND ANIMALS)
# 6                     (PLASTERS IN TIN CIRCUS PARADE)
# 7                          (PLASTERS IN TIN SPACEBOY)
# 8                  (PLASTERS IN TIN WOODLAND ANIMALS)
# 9                          (PLASTERS IN TIN SPACEBOY)
# 10                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 11                               (RABBIT NIGHT LIGHT)
# 12                         (RED RETROSPOT MINI CASES)
# 13                    (RED TOADSTOOL LED NIGHT LIGHT)
# 14                         (REGENCY CAKESTAND 3 TIER)
# 15               (ROUND SNACK BOXES SET OF4 WOODLAND)
# 16               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 17                      (SET/6 RED SPOTTY PAPER CUPS)
# 18                    (SET/6 RED SPOTTY PAPER PLATES)
# 19                (STRAWBERRY LUNCH BOX WITH CUTLERY)
# 20               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 21                      (SET/6 RED SPOTTY PAPER CUPS)
# 22               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 23                    (SET/6 RED SPOTTY PAPER PLATES)
# 24                    (SET/6 RED SPOTTY PAPER PLATES)
# 25                      (SET/6 RED SPOTTY PAPER CUPS)
# 26           (POSTAGE, SET/6 RED SPOTTY PAPER PLATES)
# 27             (POSTAGE, SET/6 RED SPOTTY PAPER CUPS)
# 28  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...
# 29                    (SET/6 RED SPOTTY PAPER PLATES)
# 30                      (SET/6 RED SPOTTY PAPER CUPS)
#
#                                  consequents  antecedent support  \
# 0                                  (POSTAGE)            0.125000
# 1                                  (POSTAGE)            0.153061
# 2                                  (POSTAGE)            0.117347
# 3                                  (POSTAGE)            0.142857
# 4         (PLASTERS IN TIN WOODLAND ANIMALS)            0.168367
# 5            (PLASTERS IN TIN CIRCUS PARADE)            0.170918
# 6                                  (POSTAGE)            0.168367
# 7         (PLASTERS IN TIN WOODLAND ANIMALS)            0.137755
# 8                 (PLASTERS IN TIN SPACEBOY)            0.170918
# 9                                  (POSTAGE)            0.137755
# 10                                 (POSTAGE)            0.170918
# 11                                 (POSTAGE)            0.188776
# 12                                 (POSTAGE)            0.137755
# 13                                 (POSTAGE)            0.181122
# 14                                 (POSTAGE)            0.125000
# 15                                 (POSTAGE)            0.158163
# 16                                 (POSTAGE)            0.132653
# 17                                 (POSTAGE)            0.137755
# 18                                 (POSTAGE)            0.127551
# 19                                 (POSTAGE)            0.122449
# 20             (SET/6 RED SPOTTY PAPER CUPS)            0.132653
# 21      (SET/20 RED RETROSPOT PAPER NAPKINS)            0.137755
# 22           (SET/6 RED SPOTTY PAPER PLATES)            0.132653
# 23      (SET/20 RED RETROSPOT PAPER NAPKINS)            0.127551
# 24             (SET/6 RED SPOTTY PAPER CUPS)            0.127551
# 25           (SET/6 RED SPOTTY PAPER PLATES)            0.137755
# 26             (SET/6 RED SPOTTY PAPER CUPS)            0.107143
# 27           (SET/6 RED SPOTTY PAPER PLATES)            0.117347
# 28                                 (POSTAGE)            0.122449
# 29    (POSTAGE, SET/6 RED SPOTTY PAPER CUPS)            0.127551
# 30  (POSTAGE, SET/6 RED SPOTTY PAPER PLATES)            0.137755
#
#     consequent support   support  confidence      lift  representativity  \
# 0             0
# 23  0.085121    4.336735       0.956140  0.645161   0.769412    0.784615
# 24  0.104878   21.556122       0.981725  0.857143   0.953609    0.924444
# 25  0.104878    7.852041       0.993343  0.857143   0.872645    0.924444
# 26  0.087281   18.107143       0.958000  0.714286   0.944773    0.846561
# 27  0.087073    6.688776       0.966763  0.714286   0.850496    0.834783
# 28  0.008330    1.408163       0.093023  0.129870   0.289855    0.483333
# 29  0.087073    4.413265       0.978070  0.714286   0.773410    0.834783
# 30  0.087281    3.443878       0.992012  0.714286   0.709630    0.846561

# %%
germany_rules=get_rules(data, 'Germany', 0.1, 0.5)
germany_rules
# Out:
#                                           antecedents  \
# 0                     (PLASTERS IN TIN CIRCUS PARADE)
# 1                          (PLASTERS IN TIN SPACEBOY)
# 2                  (PLASTERS IN TIN WOODLAND ANIMALS)
# 3                          (REGENCY CAKESTAND 3 TIER)
# 4                 (ROUND SNACK BOXES SET OF 4 FRUITS)
# 5                (ROUND SNACK BOXES SET OF4 WOODLAND)
# 6                            (WOODLAND CHARLOTTE BAG)
# 7                (ROUND SNACK BOXES SET OF4 WOODLAND)
# 8                 (ROUND SNACK BOXES SET OF 4 FRUITS)
# 9       (POSTAGE, ROUND SNACK BOXES SET OF4 WOODLAND)
# 10       (POSTAGE, ROUND SNACK BOXES SET OF 4 FRUITS)
# 11  (ROUND SNACK BOXES SET OF 4 FRUITS, ROUND SNAC...
# 12               (ROUND SNACK BOXES SET OF4 WOODLAND)
# 13                (ROUND SNACK BOXES SET OF 4 FRUITS)
#
#                                       consequents  antecedent support  \
# 0                                       (POSTAGE)            0.115974
# 1                                       (POSTAGE)            0.107221
# 2                                       (POSTAGE)            0.137856
# 3                                       (POSTAGE)            0.137856
# 4                                       (POSTAGE)            0.157549
# 5                                       (POSTAGE)            0.245077
# 6                                       (POSTAGE)            0.126915
# 7             (ROUND SNACK BOXES SET OF 4 FRUITS)            0.245077
# 8            (ROUND SNACK BOXES SET OF4 WOODLAND)            0.157549
# 9             (ROUND SNACK BOXES SET OF 4 FRUITS)            0.225383
# 10           (ROUND SNACK BOXES SET OF4 WOODLAND)            0.150985
# 11                                      (POSTAGE)            0.131291
# 12   (POSTAGE, ROUND SNACK BOXES SET OF 4 FRUITS)            0.245077
# 13  (POSTAGE, ROUND SNACK BOXES SET OF4 WOODLAND)            0.157549
#
#     consequent support   support  confidence      lift  representativity  \
# 0             0.818381  0.100656    0.867925  1.060539               1.0
# 1             0.818381  0.100656    0.938776  1.147113               1.0
# 2             0.818381  0.118162    0.857143  1.047364               1.0
# 3             0.818381  0.120350    0.873016  1.066760               1.0
# 4             0.818381  0.150985    0.958333  1.171012               1.0
# 5             0.818381  0.225383    0.919643  1.123735               1.0
# 6             0.818381  0.115974    0.913793  1.116587               1.0
# 7             0.157549  0.131291    0.535714  3.400298               1.0
# 8             0.245077  0.131291    0.833333  3.400298               1.0
# 9             0.157549  0.124726    0.553398  3.512540               1.0
# 10            0.245077  0.124726    0.826087  3.370730               1.0
# 11            0.818381  0.124726    0.950000  1.160829               1.0
# 12            0.150985  0.124726    0.508929  3.370730               1.0
# 13            0.225383  0.124726    0.791667  3.512540               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0   0.005746    1.375117       0.064572  0.120735   0.272789    0.495460
# 1   0.012909    2.966448       0.143649  0.122016   0.662896    0.530885
# 2   0.005344    1.271335       0.052453  0.140992   0.213425    0.500764
# 3   0.007532    1.430252       0.072589  0.143979   0.300822    0.510037
# 4   0.022049    4.358862       0.173348  0.183024   0.770582    0.571413
# 5   0.024817    2.260151       0.145856  0.268930   0.557552    0.597522
# 6   0.012109    2.106783       0.119591  0.139842   0.525343    0.527752
# 7   0.092679    1.814509       0.935072  0.483871   0.448887    0.684524
# 8   0.092679    4.529540       0.837922  0.483871   0.779227    0.684524
# 9   0.089218    1.886357       0.923431  0.483051   0.469878    0.672532
# 10  0.087724    4.340810       0.828405  0.459677   0.769628    0.667508
# 11  0.017280    3.632385       0.159486  0.151194   0.724699    0.551203
# 12  0.087724    1.728904       0.931655  0.459677   0.421599    0.667508
# 13  0.089218    3.718162       0.849077  0.483051   0.731050    0.672532

# %%
spain_rules=get_rules(data, 'Spain', 0.1, 0.5)
spain_rules
# Out:
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#                                           antecedents  \
# 0                            (6 RIBBONS RUSTIC CHARM)
# 1                     (ASSORTED COLOUR BIRD ORNAMENT)
# 2                            (6 RIBBONS RUSTIC CHARM)
# 3                     (ASSORTED COLOUR BIRD ORNAMENT)
# 4               (CLASSIC METAL BIRDCAGE PLANT HOLDER)
# 5                   (PACK OF 72 RETROSPOT CAKE CASES)
# 6                          (REGENCY CAKESTAND 3 TIER)
# 7                   (POSTAGE, 6 RIBBONS RUSTIC CHARM)
# 8            (POSTAGE, ASSORTED COLOUR BIRD ORNAMENT)
# 9   (6 RIBBONS RUSTIC CHARM, ASSORTED COLOUR BIRD ...
# 10                           (6 RIBBONS RUSTIC CHARM)
# 11                    (ASSORTED COLOUR BIRD ORNAMENT)
#
#                                  consequents  antecedent support  \
# 0            (ASSORTED COLOUR BIRD ORNAMENT)            0.166667
# 1                   (6 RIBBONS RUSTIC CHARM)            0.133333
# 2                                  (POSTAGE)            0.166667
# 3                                  (POSTAGE)            0.133333
# 4                                  (POSTAGE)            0.111111
# 5                                  (POSTAGE)            0.122222
# 6                                  (POSTAGE)            0.244444
# 7            (ASSORTED COLOUR BIRD ORNAMENT)            0.144444
# 8                   (6 RIBBONS RUSTIC CHARM)            0.122222
# 9                                  (POSTAGE)            0.100000
# 10  (POSTAGE, ASSORTED COLOUR BIRD ORNAMENT)            0.166667
# 11         (POSTAGE, 6 RIBBONS RUSTIC CHARM)            0.133333
#
#     consequent support   support  confidence      lift  representativity  \
# 0             0.133333  0.100000    0.600000  4.500000               1.0
# 1             0.166667  0.100000    0.750000  4.500000               1.0
# 2             0.688889  0.144444    0.866667  1.258065               1.0
# 3             0.688889  0.122222    0.916667  1.330645               1.0
# 4             0.688889  0.100000    0.900000  1.306452               1.0
# 5             0.688889  0.122222    1.000000  1.451613               1.0
# 6             0.688889  0.188889    0.772727  1.121701               1.0
# 7             0.133333  0.100000    0.692308  5.192308               1.0
# 8             0.166667  0.100000    0.818182  4.909091               1.0
# 9             0.688889  0.100000    1.000000  1.451613               1.0
# 10            0.122222  0.100000    0.600000  4.909091               1.0
# 11            0.144444  0.100000    0.750000  5.192308               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0   0.077778    2.166667       0.933333  0.500000   0.538462    0.675000
# 1   0.077778    3.333333       0.897436  0.500000   0.700000    0.675000
# 2   0.029630    2.333333       0.246154  0.203125   0.571429    0.538172
# 3   0.030370    3.733333       0.286713  0.174603   0.732143    0.547043
# 4   0.023457    3.111111       0.263889  0.142857   0.678571    0.522581
# 5   0.038025         inf       0.354430  0.177419   1.000000    0.588710
# 6   0.020494    1.368889       0.143599  0.253731   0.269481    0.523460
# 7   0.080741    2.816667       0.943723  0.562500   0.644970    0.721154
# 8   0.079630    4.583333       0.907173  0.529412   0.781818    0.709091
# 9   0.031111         inf       0.345679  0.145161   1.000000    0.572581
# 10  0.079630    2.194444       0.955556  0.529412   0.544304    0.709091
# 11  0.080741    3.422222       0.931624  0.562500   0.707792    0.721154
