# %%
#https://bab2min.github.io/tomotopy/v0.12.2/en/
# !pip install tomotopy
import tomotopy as tp
from nltk.corpus import stopwords
import re
# Out:
# Collecting tomotopy
#   Downloading tomotopy-0.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (30 kB)
# Requirement already satisfied: numpy<2,>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tomotopy) (1.26.4)
# Downloading tomotopy-0.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 35.5 MB/s eta 0:00:00
# Installing collected packages: tomotopy
# Successfully installed tomotopy-0.13.0

# %%
def tokenizer(doc,sw):
    return [word for word in [re.sub('[^a-z]','',x.lower()) for x in doc.strip().split()] if word not in sw and len(word)>2]

# %%
import nltk
nltk.download('stopwords')
sw=stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
#new LDA model
lda = tp.LDAModel(k=20)

#add the docs to the model
with open('news.txt') as f:
    for doc in f:
        lda.add_doc(tokenizer(doc,sw))


#train LDA model
for i in range(0, 500,10):
    lda.train(10)
    print('Iteration: {}\tLog-likelihood: {}'.format(i, lda.ll_per_word))
# Out:
# Iteration: 0	Log-likelihood: -9.608629677285904
# Iteration: 10	Log-likelihood: -9.244774645498078
# Iteration: 20	Log-likelihood: -9.113314329926652
# Iteration: 30	Log-likelihood: -9.03532878439616
# Iteration: 40	Log-likelihood: -8.986184805127891
# Iteration: 50	Log-likelihood: -8.942659970489162
# Iteration: 60	Log-likelihood: -8.91348108828767
# Iteration: 70	Log-likelihood: -8.893295935390357
# Iteration: 80	Log-likelihood: -8.875172913803205
# Iteration: 90	Log-likelihood: -8.860117688409412
# Iteration: 100	Log-likelihood: -8.85084218469821
# Iteration: 110	Log-likelihood: -8.837665412578431
# Iteration: 120	Log-likelihood: -8.82859103167647
# Iteration: 130	Log-likelihood: -8.818253583619517
# Iteration: 140	Log-likelihood: -8.811934981797938
# Iteration: 150	Log-likelihood: -8.80577383918074
# Iteration: 160	Log-likelihood: -8.797974272125309
# Iteration: 170	Log-likelihood: -8.792883052264344
# Iteration: 180	Log-likelihood: -8.78642023927764
# Iteration: 190	Log-likelihood: -8.782061688600821
# Iteration: 200	Log-likelihood: -8.780574221296247
# Iteration: 210	Log-likelihood: -8.774215991864907
# Iteration: 220	Log-likelihood: -8.772471800311912
# Iteration: 230	Log-likelihood: -8.766784545431463
# Iteration: 240	Log-likelihood: -8.761849884411852
# Iteration: 250	Log-likelihood: -8.75866267149036
# Iteration: 260	Log-likelihood: -8.755772817588726
# Iteration: 270	Log-likelihood: -8.754395788120208
# Iteration: 280	Log-likelihood: -8.74794128002893
# Iteration: 290	Log-likelihood: -8.746035633817188
# Iteration: 300	Log-likelihood: -8.74420391125213
# Iteration: 310	Log-likelihood: -8.740728570217449
# Iteration: 320	Log-likelihood: -8.734807431018996
# Iteration: 330	Log-likelihood: -8.73398976984509
# Iteration: 340	Log-likelihood: -8.73018924838197
# Iteration: 350	Log-likelihood: -8.730627818020347
# Iteration: 360	Log-likelihood: -8.729593862540588
# Iteration: 370	Log-likelihood: -8.726986507267855
# Iteration: 380	Log-likelihood: -8.723052872676735
# Iteration: 390	Log-likelihood: -8.722398423702538
# Iteration: 400	Log-likelihood: -8.723278262602916
# Iteration: 410	Log-likelihood: -8.72102059142162
# Iteration: 420	Log-likelihood: -8.716822415679003
# Iteration: 430	Log-likelihood: -8.718164034223783
# Iteration: 440	Log-likelihood: -8.714440076214313
# Iteration: 450	Log-likelihood: -8.717463171070722
# Iteration: 460	Log-likelihood: -8.714229484315018
# Iteration: 470	Log-likelihood: -8.713892769274123
# Iteration: 480	Log-likelihood: -8.71275907026672
# Iteration: 490	Log-likelihood: -8.711828504345961

# %%
#print doc info
for doc in lda.docs:
    print ([round(p,2) for p in doc.get_topic_dist()])
    print()
    break
# Out:
# [0.0, 0.54, 0.0, 0.01, 0.0, 0.02, 0.0, 0.07, 0.02, 0.0, 0.0, 0.05, 0.0, 0.01, 0.0, 0.03, 0.0, 0.0, 0.11, 0.12]

# %%
#print topic info
for k in range(lda.k):

    topk_words=[pair[0] for pair in lda.get_topic_words(k, top_n=15)]
    print(k,topk_words)
    print()
# Out:
# 0 ['music', 'show', 'number', 'new', 'one', 'band', 'album', 'song', 'also', 'top', 'last', 'first', 'year', 'three', 'best']
#
# 1 ['said', 'government', 'people', 'would', 'tax', 'also', 'money', 'public', 'report', 'local', 'aid', 'plans', 'pay', 'council', 'years']
#
# 2 ['england', 'wales', 'ireland', 'game', 'rugby', 'six', 'nations', 'france', 'side', 'first', 'coach', 'players', 'scotland', 'win', 'back']
#
# 3 ['said', 'china', 'sales', 'car', 'new', 'chinese', 'year', 'fiat', 'market', 'chinas', 'company', 'three', 'europe', 'profits', 'production']
#
# 4 ['games', 'music', 'game', 'digital', 'new', 'also', 'technology', 'said', 'video', 'players', 'gaming', 'market', 'apple', 'media', 'people']
#
# 5 ['mobile', 'people', 'phone', 'said', 'technology', 'broadband', 'phones', 'services', 'service', 'use', 'million', 'users', 'access', 'net', 'customers']
#
# 6 ['film', 'best', 'awards', 'award', 'films', 'director', 'also', 'actor', 'actress', 'said', 'years', 'comedy', 'star', 'movie', 'prize']
#
# 7 ['said', 'new', 'companies', 'could', 'many', 'may', 'firms', 'information', 'rules', 'action', 'already', 'allow', 'industry', 'future', 'news']
#
# 8 ['said', 'told', 'made', 'lord', 'former', 'also', 'would', 'public', 'week', 'added', 'chief', 'saying', 'first', 'last', 'since']
#
# 9 ['club', 'game', 'united', 'chelsea', 'league', 'football', 'players', 'liverpool', 'play', 'manager', 'arsenal', 'manchester', 'season', 'cup', 'boss']
#
# 10 ['said', 'court', 'case', 'drugs', 'charges', 'also', 'guilty', 'ban', 'trial', 'fraud', 'hunting', 'law', 'decision', 'former', 'legal']
#
# 11 ['labour', 'election', 'party', 'blair', 'said', 'would', 'brown', 'howard', 'prime', 'minister', 'tory', 'leader', 'tories', 'chancellor', 'tony']
#
# 12 ['said', 'software', 'users', 'people', 'security', 'search', 'net', 'site', 'email', 'information', 'sites', 'internet', 'computer', 'web', 'microsoft']
#
# 13 ['world', 'first', 'win', 'set', 'final', 'open', 'champion', 'last', 'second', 'title', 'year', 'said', 'match', 'australian', 'two']
#
# 14 ['said', 'home', 'police', 'would', 'rights', 'government', 'people', 'law', 'without', 'secretary', 'plans', 'human', 'house', 'new', 'clarke']
#
# 15 ['said', 'year', 'growth', 'economy', 'economic', 'prices', 'market', 'sales', 'rise', 'last', 'figures', 'expected', 'however', 'quarter', 'bank']
#
# 16 ['company', 'said', 'firm', 'shares', 'deal', 'would', 'yukos', 'chief', 'oil', 'financial', 'market', 'bank', 'also', 'stock', 'business']
#
# 17 ['children', 'school', 'women', 'education', 'life', 'young', 'university', 'students', 'family', 'project', 'schools', 'age', 'parents', 'world', 'research']
#
# 18 ['said', 'would', 'one', 'get', 'time', 'like', 'could', 'way', 'think', 'going', 'people', 'good', 'make', 'see', 'well']
#
# 19 ['said', 'european', 'would', 'countries', 'government', 'foreign', 'world', 'country', 'bill', 'international', 'europe', 'president', 'could', 'united', 'states']
