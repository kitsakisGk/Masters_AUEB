# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ### Imports

# %%
import gc
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
# %matplotlib inline

from tensorflow.keras import backend as K # Importing Keras backend (by default it is Tensorflow)
from tensorflow.keras.callbacks import EarlyStopping # Callback for early stopping
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Conv2D, Dense, Dropout, Flatten, MaxPool2D # Layers to be used for building our model
from tensorflow.keras.models import Model # The class used to create a model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.random import set_seed

print("Tensorflow version " + tf.__version__)
# Out:
# Tensorflow version 2.19.0

# %% [markdown]
# ### Data manipulation
#
# **Task**: Given an image of handwritten digit find the digit
#
# **Data**:
# - The data are grayscale 28*28 images of scanned handwritten digits
# - We will use a CNN to classify them (no need to flatten as when using an MLP)
# - The values of the inputs are in [0, 255] so we normalize them to [0, 1]

# %%
batch_size = 128
classes = 10
epochs = 100

(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)
input_shape = (28, 28, 1)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255
Y_train = to_categorical(y_train, classes)
Y_test = to_categorical(y_test, classes)

# %% [markdown]
# ### Plotting results

# %%
def plot_history(hs, epochs, metric):
    print()
    plt.style.use('dark_background')
    plt.rcParams['figure.figsize'] = [15, 8]
    plt.rcParams['font.size'] = 16
    plt.clf()
    for label in hs:
        plt.plot(hs[label].history[metric], label='{0:s} train {1:s}'.format(label, metric), linewidth=2)
        plt.plot(hs[label].history['val_{0:s}'.format(metric)], label='{0:s} validation {1:s}'.format(label, metric), linewidth=2)
    x_ticks = np.arange(0, epochs + 1, epochs / 10)
    x_ticks [0] += 1
    plt.xticks(x_ticks)
    plt.ylim((0, 1))
    plt.xlabel('Epochs')
    plt.ylabel('Loss' if metric=='loss' else 'Accuracy')
    plt.legend()
    plt.show()

# %% [markdown]
# ### Cleaning up

# %%
def clean_up(model):
    K.clear_session()
    del model
    gc.collect()

# %% [markdown]
# ### Model creation
#
# - We will use a Functional Model.
#     - It is more flexible than the `Sequential` model but ...
#     - We need to be careful with the sizes of the layers.
# - The first layer should always be an `Input` layer where we specify the input of the model, e.g., the training data
# - The other layers can be whatever we want and for each layer we must:
#     - Define the input to the layer, i.e., another layer.
#     - Define the number of units which also defines the output size.
#         - The output size must be always equal to the number of units of the next layer.

# %%
def train_model(
        optimizer,
        epochs=100,
        batch_size=128,
        conv_layers=2,
        conv_activation='relu',
        conv_dropout=False,
        output_activation='softmax',
        callbacks=None,
        verbose=0):

    np.random.seed(1402) # Define the seed for numpy to have reproducible experiments.
    set_seed(1981) # Define the seed for Tensorflow to have reproducible experiments.

    # Define the input layer.
    input = Input(
        shape=input_shape,
        name='Input'
    )

    x = input
    # Define the convolutional layers.
    for i in range(conv_layers):
        x = Conv2D(
            filters=8*(2**i),
            kernel_size=(3, 3),
            strides=(1, 1),
            padding='same',
            dilation_rate=(1, 1),
            activation=conv_activation,
            name='Conv2D-{0:d}'.format(i + 1)
        )(x)
        x = MaxPool2D(
            pool_size=(2, 2),
            strides=(2, 2),
            padding='same',
            name='MaxPool2D-{0:d}'.format(i + 1)
        )(x)
        if conv_dropout:
            x = Dropout(
                rate=0.2,
                name='Dropout-{0:d}'.format(i + 1)
            )(x)
    # Flatten the convolved images so as to input them to a Dense Layer
    x = Flatten(name='Flatten')(x)

    # Define the output layer.
    output = Dense(
        units=classes,
        activation=output_activation,
        name='Output'
    )(x)

    # Define the model and train it.
    model = Model(inputs=input, outputs=output)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    hs = model.fit(
        x=X_train,
        y=Y_train,
        validation_split=0.1, # use 10% of the training data as validation data
        epochs=epochs,
        verbose=verbose,
        callbacks=callbacks,
        batch_size=batch_size
    )
    print('Finished training.')
    print('------------------')
    model.summary() # Print a description of the model.
    return model, hs

# %% [markdown]
# ### Without dropout

# %%
# Using Adam
optimizer = Adam()

# 3 Convolutional Layers and Logistic Regression
conv_no_drop_model_adam, conv_no_drop_hs_adam = train_model(
    optimizer=optimizer,
    epochs=epochs,
    batch_size=batch_size,
    conv_layers=3,
    conv_activation='relu',
    conv_dropout=False,
    output_activation='softmax'
)

# Evaluate on test data and show all the results.
conv_no_drop_eval_adam = conv_no_drop_model_adam.evaluate(X_test, Y_test, verbose=1)
clean_up(model=conv_no_drop_model_adam)
# Out:
# Finished training.
# ------------------
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Input (InputLayer)              │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv2D-1 (Conv2D)               │ (None, 28, 28, 8)      │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MaxPool2D-1 (MaxPooling2D)      │ (None, 14, 14, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv2D-2 (Conv2D)               │ (None, 14, 14, 16)     │         1,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MaxPool2D-2 (MaxPooling2D)      │ (None, 7, 7, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv2D-3 (Conv2D)               │ (None, 7, 7, 32)       │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MaxPool2D-3 (MaxPooling2D)      │ (None, 4, 4, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Flatten (Flatten)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output (Dense)                  │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 33,056 (129.13 KB)
#  Trainable params: 11,018 (43.04 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 22,038 (86.09 KB)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9899 - loss: 0.0895

# %% [markdown]
# ### Results without dropout

# %%
print("Train Loss     : {0:.5f}".format(conv_no_drop_hs_adam.history['loss'][-1]))
print("Validation Loss: {0:.5f}".format(conv_no_drop_hs_adam.history['val_loss'][-1]))
print("Test Loss      : {0:.5f}".format(conv_no_drop_eval_adam[0]))
print("---")
print("Train Accuracy     : {0:.5f}".format(conv_no_drop_hs_adam.history['accuracy'][-1]))
print("Validation Accuracy: {0:.5f}".format(conv_no_drop_hs_adam.history['val_accuracy'][-1]))
print("Test Accuracy      : {0:.5f}".format(conv_no_drop_eval_adam[1]))


# Plot train and validation error per epoch.
plot_history(hs={'Conv No Drop': conv_no_drop_hs_adam}, epochs=epochs, metric='loss')
plot_history(hs={'Conv No Drop': conv_no_drop_hs_adam}, epochs=epochs, metric='accuracy')
# Out:
# Train Loss     : 0.00000
# Validation Loss: 0.06868
# Test Loss      : 0.07135
# ---
# Train Accuracy     : 1.00000
# Validation Accuracy: 0.99167
# Test Accuracy      : 0.99230

# %% [markdown]
# ### With dropout 0.2

# %%
# Using Adam
optimizer = Adam()

# 3 Convolutional Layers and Logistic Regression
conv_drop_eval_model_adam, conv_drop_hs_adam = train_model(
    optimizer=optimizer,
    epochs=epochs,
    batch_size=batch_size,
    conv_layers=3,
    conv_activation='relu',
    conv_dropout=True,
    output_activation='softmax'
)

# Evaluate on test data and show all the results.
conv_drop_eval_adam = conv_drop_eval_model_adam.evaluate(X_test, Y_test, verbose=1)
clean_up(model=conv_drop_eval_model_adam)
# Out:
# Finished training.
# ------------------
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Input (InputLayer)              │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv2D-1 (Conv2D)               │ (None, 28, 28, 8)      │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MaxPool2D-1 (MaxPooling2D)      │ (None, 14, 14, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dropout-1 (Dropout)             │ (None, 14, 14, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv2D-2 (Conv2D)               │ (None, 14, 14, 16)     │         1,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MaxPool2D-2 (MaxPooling2D)      │ (None, 7, 7, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dropout-2 (Dropout)             │ (None, 7, 7, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv2D-3 (Conv2D)               │ (None, 7, 7, 32)       │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MaxPool2D-3 (MaxPooling2D)      │ (None, 4, 4, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dropout-3 (Dropout)             │ (None, 4, 4, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Flatten (Flatten)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output (Dense)                  │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 33,056 (129.13 KB)
#  Trainable params: 11,018 (43.04 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 22,038 (86.09 KB)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9906 - loss: 0.0242

# %% [markdown]
# ### No dropout vs. dropout = 0.2

# %%
print("Train Loss     : {0:.5f}".format(conv_drop_hs_adam.history['loss'][-1]))
print("Validation Loss: {0:.5f}".format(conv_drop_hs_adam.history['val_loss'][-1]))
print("Test Loss      : {0:.5f}".format(conv_drop_eval_adam[0]))
print("---")
print("Train Accuracy     : {0:.5f}".format(conv_drop_hs_adam.history['accuracy'][-1]))
print("Validation Accuracy: {0:.5f}".format(conv_drop_hs_adam.history['val_accuracy'][-1]))
print("Test Accuracy      : {0:.5f}".format(conv_drop_eval_adam[1]))


# Plot train and validation error per epoch.
plot_history(
    hs={
        'Conv No Drop': conv_no_drop_hs_adam,
        'Conv Drop (0.2)': conv_drop_hs_adam
    },
    epochs=epochs,
    metric='loss'
)
plot_history(
    hs={
        'Conv No Drop': conv_no_drop_hs_adam,
        'Conv Drop (0.2)': conv_drop_hs_adam
    },
    epochs=epochs,
    metric='accuracy'
)
# Out:
# Train Loss     : 0.03472
# Validation Loss: 0.02647
# Test Loss      : 0.02059
# ---
# Train Accuracy     : 0.98835
# Validation Accuracy: 0.99167
# Test Accuracy      : 0.99250

# %% [markdown]
# ###Using Early Stopping with patience 10

# %%
# Using Adam
optimizer = Adam()

early_stopping = EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    verbose=1,
    restore_best_weights=True
)

# 3 Convolutional Layers and Logistic Regression
conv_drop_es_10_eval_model_adam, conv_drop_es_10_hs_adam = train_model(
    optimizer=optimizer,
    epochs=epochs,
    batch_size=batch_size,
    conv_layers=3,
    conv_activation='relu',
    conv_dropout=True,
    output_activation='softmax',
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate on test data and show all the results.
conv_drop_es_10_eval_adam = conv_drop_es_10_eval_model_adam.evaluate(X_test, Y_test, verbose=1)
clean_up(model=conv_drop_es_10_eval_model_adam)
# Out:
# Epoch 1/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.6058 - loss: 1.1707 - val_accuracy: 0.9642 - val_loss: 0.1291
# Epoch 2/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9308 - loss: 0.2222 - val_accuracy: 0.9767 - val_loss: 0.0856
# Epoch 3/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9482 - loss: 0.1639 - val_accuracy: 0.9820 - val_loss: 0.0657
# Epoch 4/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9583 - loss: 0.1387 - val_accuracy: 0.9837 - val_loss: 0.0585
# Epoch 5/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9609 - loss: 0.1227 - val_accuracy: 0.9838 - val_loss: 0.0545
# Epoch 6/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9641 - loss: 0.1139 - val_accuracy: 0.9852 - val_loss: 0.0510
# Epoch 7/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9690 - loss: 0.1001 - val_accuracy: 0.9878 - val_loss: 0.0446
# Epoch 8/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9708 - loss: 0.0931 - val_accuracy: 0.9890 - val_loss: 0.0422
# Epoch 9/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9709 - loss: 0.0890 - val_accuracy: 0.9900 - val_loss: 0.0392
# Epoch 10/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9748 - loss: 0.0813 - val_accuracy: 0.9902 - val_loss: 0.0379
# Epoch 11/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9750 - loss: 0.0800 - val_accuracy: 0.9913 - val_loss: 0.0342
# Epoch 12/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9761 - loss: 0.0747 - val_accuracy: 0.9902 - val_loss: 0.0354
# Epoch 13/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9764 - loss: 0.0729 - val_accuracy: 0.9903 - val_loss: 0.0341
# Epoch 14/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9779 - loss: 0.0699 - val_accuracy: 0.9907 - val_loss: 0.0330
# Epoch 15/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9788 - loss: 0.0651 - val_accuracy: 0.9913 - val_loss: 0.0330
# Epoch 16/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9787 - loss: 0.0634 - val_accuracy: 0.9922 - val_loss: 0.0314
# Epoch 17/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9789 - loss: 0.0649 - val_accuracy: 0.9913 - val_loss: 0.0311
# Epoch 18/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9812 - loss: 0.0595 - val_accuracy: 0.9925 - val_loss: 0.0301
# Epoch 19/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9801 - loss: 0.0613 - val_accuracy: 0.9920 - val_loss: 0.0308
# Epoch 20/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9817 - loss: 0.0583 - val_accuracy: 0.9925 - val_loss: 0.0312
# Epoch 21/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9813 - loss: 0.0589 - val_accuracy: 0.9920 - val_loss: 0.0299
# Epoch 22/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9817 - loss: 0.0568 - val_accuracy: 0.9927 - val_loss: 0.0289
# Epoch 23/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9828 - loss: 0.0549 - val_accuracy: 0.9918 - val_loss: 0.0293
# Epoch 24/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9822 - loss: 0.0550 - val_accuracy: 0.9928 - val_loss: 0.0270
# Epoch 25/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9825 - loss: 0.0525 - val_accuracy: 0.9922 - val_loss: 0.0271
# Epoch 26/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9831 - loss: 0.0494 - val_accuracy: 0.9937 - val_loss: 0.0261
# Epoch 27/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9826 - loss: 0.0524 - val_accuracy: 0.9928 - val_loss: 0.0273
# Epoch 28/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9826 - loss: 0.0523 - val_accuracy: 0.9930 - val_loss: 0.0267
# Epoch 29/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9841 - loss: 0.0493 - val_accuracy: 0.9920 - val_loss: 0.0270
# Epoch 30/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9847 - loss: 0.0464 - val_accuracy: 0.9928 - val_loss: 0.0265
# Epoch 31/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9851 - loss: 0.0470 - val_accuracy: 0.9937 - val_loss: 0.0266
# Epoch 32/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9852 - loss: 0.0462 - val_accuracy: 0.9942 - val_loss: 0.0242
# Epoch 33/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9856 - loss: 0.0454 - val_accuracy: 0.9925 - val_loss: 0.0255
# Epoch 34/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9843 - loss: 0.0451 - val_accuracy: 0.9937 - val_loss: 0.0247
# Epoch 35/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9842 - loss: 0.0461 - val_accuracy: 0.9937 - val_loss: 0.0251
# Epoch 36/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9844 - loss: 0.0480 - val_accuracy: 0.9928 - val_loss: 0.0257
# Epoch 37/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9854 - loss: 0.0439 - val_accuracy: 0.9933 - val_loss: 0.0254
# Epoch 38/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9853 - loss: 0.0454 - val_accuracy: 0.9933 - val_loss: 0.0267
# Epoch 39/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9848 - loss: 0.0471 - val_accuracy: 0.9935 - val_loss: 0.0256
# Epoch 40/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9861 - loss: 0.0423 - val_accuracy: 0.9923 - val_loss: 0.0293
# Epoch 41/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9860 - loss: 0.0438 - val_accuracy: 0.9937 - val_loss: 0.0256
# Epoch 42/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9862 - loss: 0.0440 - val_accuracy: 0.9932 - val_loss: 0.0248
# Epoch 42: early stopping
# Restoring model weights from the end of the best epoch: 32.
# Finished training.
# ------------------
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Input (InputLayer)              │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv2D-1 (Conv2D)               │ (None, 28, 28, 8)      │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MaxPool2D-1 (MaxPooling2D)      │ (None, 14, 14, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dropout-1 (Dropout)             │ (None, 14, 14, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv2D-2 (Conv2D)               │ (None, 14, 14, 16)     │         1,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MaxPool2D-2 (MaxPooling2D)      │ (None, 7, 7, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dropout-2 (Dropout)             │ (None, 7, 7, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv2D-3 (Conv2D)               │ (None, 7, 7, 32)       │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MaxPool2D-3 (MaxPooling2D)      │ (None, 4, 4, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dropout-3 (Dropout)             │ (None, 4, 4, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Flatten (Flatten)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output (Dense)                  │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 33,056 (129.13 KB)
#  Trainable params: 11,018 (43.04 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 22,038 (86.09 KB)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9904 - loss: 0.0283

# %%
print("Train Loss     : {0:.5f}".format(conv_drop_es_10_hs_adam.history['loss'][-1]))
print("Validation Loss: {0:.5f}".format(conv_drop_es_10_hs_adam.history['val_loss'][-1]))
print("Test Loss      : {0:.5f}".format(conv_drop_es_10_eval_adam[0]))
print("---")
print("Train Accuracy     : {0:.5f}".format(conv_drop_es_10_hs_adam.history['accuracy'][-1]))
print("Validation Accuracy: {0:.5f}".format(conv_drop_es_10_hs_adam.history['val_accuracy'][-1]))
print("Test Accuracy      : {0:.5f}".format(conv_drop_es_10_eval_adam[1]))


# Plot train and validation error per epoch.
plot_history(
    hs={
        'Conv Drop (0.2) ES (10)': conv_drop_es_10_hs_adam
    },
    epochs=epochs,
    metric='loss'
)
plot_history(
    hs={
        'Conv Drop (0.2) ES (10)': conv_drop_es_10_hs_adam
    },
    epochs=epochs,
    metric='accuracy'
)
# Out:
# Train Loss     : 0.04262
# Validation Loss: 0.02484
# Test Loss      : 0.02407
# ---
# Train Accuracy     : 0.98635
# Validation Accuracy: 0.99317
# Test Accuracy      : 0.99180

# %% [markdown]
# ### Using Early Stopping with patience 20

# %%
# Using Adam
optimizer = Adam()

early_stopping = EarlyStopping(
    monitor='val_accuracy',
    patience=20,
    verbose=1,
    restore_best_weights=True
)

# 3 Convolutional Layers and Logistic Regression
conv_drop_es_20_eval_model_adam, conv_drop_es_20_hs_adam = train_model(
    optimizer=optimizer,
    epochs=epochs,
    batch_size=batch_size,
    conv_layers=3,
    conv_activation='relu',
    conv_dropout=True,
    output_activation='softmax',
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate on test data and show all the results.
conv_drop_es_20_eval_adam = conv_drop_es_20_eval_model_adam.evaluate(X_test, Y_test, verbose=1)
clean_up(model=conv_drop_es_20_eval_model_adam)
# Out:
# Epoch 1/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.6170 - loss: 1.1346 - val_accuracy: 0.9658 - val_loss: 0.1250
# Epoch 2/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9317 - loss: 0.2205 - val_accuracy: 0.9792 - val_loss: 0.0797
# Epoch 3/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9497 - loss: 0.1593 - val_accuracy: 0.9818 - val_loss: 0.0683
# Epoch 4/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9574 - loss: 0.1343 - val_accuracy: 0.9860 - val_loss: 0.0587
# Epoch 5/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9645 - loss: 0.1141 - val_accuracy: 0.9870 - val_loss: 0.0516
# Epoch 6/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9677 - loss: 0.1043 - val_accuracy: 0.9892 - val_loss: 0.0468
# Epoch 7/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9704 - loss: 0.0972 - val_accuracy: 0.9882 - val_loss: 0.0470
# Epoch 8/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9731 - loss: 0.0887 - val_accuracy: 0.9897 - val_loss: 0.0417
# Epoch 9/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9723 - loss: 0.0854 - val_accuracy: 0.9890 - val_loss: 0.0401
# Epoch 10/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9748 - loss: 0.0816 - val_accuracy: 0.9895 - val_loss: 0.0392
# Epoch 11/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9763 - loss: 0.0770 - val_accuracy: 0.9897 - val_loss: 0.0374
# Epoch 12/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9766 - loss: 0.0721 - val_accuracy: 0.9903 - val_loss: 0.0364
# Epoch 13/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9789 - loss: 0.0679 - val_accuracy: 0.9903 - val_loss: 0.0370
# Epoch 14/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9783 - loss: 0.0699 - val_accuracy: 0.9910 - val_loss: 0.0362
# Epoch 15/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9790 - loss: 0.0648 - val_accuracy: 0.9915 - val_loss: 0.0326
# Epoch 16/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9792 - loss: 0.0672 - val_accuracy: 0.9920 - val_loss: 0.0314
# Epoch 17/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9813 - loss: 0.0600 - val_accuracy: 0.9900 - val_loss: 0.0322
# Epoch 18/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9817 - loss: 0.0600 - val_accuracy: 0.9912 - val_loss: 0.0325
# Epoch 19/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9810 - loss: 0.0594 - val_accuracy: 0.9907 - val_loss: 0.0325
# Epoch 20/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9813 - loss: 0.0567 - val_accuracy: 0.9918 - val_loss: 0.0298
# Epoch 21/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9823 - loss: 0.0540 - val_accuracy: 0.9917 - val_loss: 0.0292
# Epoch 22/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9819 - loss: 0.0563 - val_accuracy: 0.9917 - val_loss: 0.0300
# Epoch 23/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9830 - loss: 0.0528 - val_accuracy: 0.9923 - val_loss: 0.0290
# Epoch 24/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9832 - loss: 0.0543 - val_accuracy: 0.9925 - val_loss: 0.0296
# Epoch 25/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9829 - loss: 0.0538 - val_accuracy: 0.9918 - val_loss: 0.0290
# Epoch 26/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9833 - loss: 0.0532 - val_accuracy: 0.9920 - val_loss: 0.0272
# Epoch 27/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9840 - loss: 0.0497 - val_accuracy: 0.9913 - val_loss: 0.0302
# Epoch 28/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9826 - loss: 0.0526 - val_accuracy: 0.9920 - val_loss: 0.0281
# Epoch 29/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9849 - loss: 0.0499 - val_accuracy: 0.9927 - val_loss: 0.0268
# Epoch 30/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9837 - loss: 0.0502 - val_accuracy: 0.9912 - val_loss: 0.0294
# Epoch 31/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9843 - loss: 0.0483 - val_accuracy: 0.9918 - val_loss: 0.0291
# Epoch 32/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9842 - loss: 0.0482 - val_accuracy: 0.9925 - val_loss: 0.0269
# Epoch 33/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9825 - loss: 0.0516 - val_accuracy: 0.9928 - val_loss: 0.0285
# Epoch 34/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9845 - loss: 0.0459 - val_accuracy: 0.9933 - val_loss: 0.0260
# Epoch 35/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9846 - loss: 0.0473 - val_accuracy: 0.9930 - val_loss: 0.0251
# Epoch 36/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9840 - loss: 0.0472 - val_accuracy: 0.9927 - val_loss: 0.0280
# Epoch 37/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9849 - loss: 0.0454 - val_accuracy: 0.9920 - val_loss: 0.0302
# Epoch 38/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9844 - loss: 0.0459 - val_accuracy: 0.9925 - val_loss: 0.0275
# Epoch 39/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9861 - loss: 0.0433 - val_accuracy: 0.9930 - val_loss: 0.0279
# Epoch 40/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9855 - loss: 0.0447 - val_accuracy: 0.9930 - val_loss: 0.0304
# Epoch 41/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9849 - loss: 0.0461 - val_accuracy: 0.9928 - val_loss: 0.0273
# Epoch 42/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9856 - loss: 0.0419 - val_accuracy: 0.9933 - val_loss: 0.0259
# Epoch 43/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9852 - loss: 0.0450 - val_accuracy: 0.9927 - val_loss: 0.0287
# Epoch 44/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9855 - loss: 0.0437 - val_accuracy: 0.9937 - val_loss: 0.0262
# Epoch 45/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9860 - loss: 0.0440 - val_accuracy: 0.9938 - val_loss: 0.0249
# Epoch 46/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9859 - loss: 0.0438 - val_accuracy: 0.9933 - val_loss: 0.0272
# Epoch 47/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9871 - loss: 0.0388 - val_accuracy: 0.9933 - val_loss: 0.0264
# Epoch 48/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9861 - loss: 0.0428 - val_accuracy: 0.9932 - val_loss: 0.0261
# Epoch 49/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9855 - loss: 0.0427 - val_accuracy: 0.9937 - val_loss: 0.0259
# Epoch 50/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9854 - loss: 0.0434 - val_accuracy: 0.9940 - val_loss: 0.0256
# Epoch 51/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9865 - loss: 0.0403 - val_accuracy: 0.9945 - val_loss: 0.0263
# Epoch 52/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9858 - loss: 0.0411 - val_accuracy: 0.9935 - val_loss: 0.0268
# Epoch 53/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9858 - loss: 0.0426 - val_accuracy: 0.9940 - val_loss: 0.0255
# Epoch 54/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9867 - loss: 0.0399 - val_accuracy: 0.9937 - val_loss: 0.0269
# Epoch 55/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9861 - loss: 0.0420 - val_accuracy: 0.9922 - val_loss: 0.0283
# Epoch 56/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9874 - loss: 0.0367 - val_accuracy: 0.9938 - val_loss: 0.0261
# Epoch 57/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9859 - loss: 0.0419 - val_accuracy: 0.9928 - val_loss: 0.0294
# Epoch 58/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9875 - loss: 0.0400 - val_accuracy: 0.9930 - val_loss: 0.0278
# Epoch 59/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9884 - loss: 0.0378 - val_accuracy: 0.9937 - val_loss: 0.0267
# Epoch 60/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9864 - loss: 0.0393 - val_accuracy: 0.9933 - val_loss: 0.0291
# Epoch 61/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9867 - loss: 0.0393 - val_accuracy: 0.9943 - val_loss: 0.0266
# Epoch 62/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9869 - loss: 0.0380 - val_accuracy: 0.9943 - val_loss: 0.0251
# Epoch 63/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9871 - loss: 0.0389 - val_accuracy: 0.9928 - val_loss: 0.0268
# Epoch 64/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9869 - loss: 0.0387 - val_accuracy: 0.9933 - val_loss: 0.0267
# Epoch 65/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9878 - loss: 0.0379 - val_accuracy: 0.9933 - val_loss: 0.0241
# Epoch 66/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9872 - loss: 0.0395 - val_accuracy: 0.9937 - val_loss: 0.0262
# Epoch 67/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9879 - loss: 0.0378 - val_accuracy: 0.9928 - val_loss: 0.0275
# Epoch 68/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9877 - loss: 0.0387 - val_accuracy: 0.9930 - val_loss: 0.0270
# Epoch 69/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9877 - loss: 0.0375 - val_accuracy: 0.9933 - val_loss: 0.0248
# Epoch 70/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9870 - loss: 0.0395 - val_accuracy: 0.9942 - val_loss: 0.0248
# Epoch 71/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9870 - loss: 0.0389 - val_accuracy: 0.9940 - val_loss: 0.0259
# Epoch 71: early stopping
# Restoring model weights from the end of the best epoch: 51.
# Finished training.
# ------------------
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Input (InputLayer)              │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv2D-1 (Conv2D)               │ (None, 28, 28, 8)      │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MaxPool2D-1 (MaxPooling2D)      │ (None, 14, 14, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dropout-1 (Dropout)             │ (None, 14, 14, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv2D-2 (Conv2D)               │ (None, 14, 14, 16)     │         1,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MaxPool2D-2 (MaxPooling2D)      │ (None, 7, 7, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dropout-2 (Dropout)             │ (None, 7, 7, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv2D-3 (Conv2D)               │ (None, 7, 7, 32)       │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MaxPool2D-3 (MaxPooling2D)      │ (None, 4, 4, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dropout-3 (Dropout)             │ (None, 4, 4, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Flatten (Flatten)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output (Dense)                  │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 33,056 (129.13 KB)
#  Trainable params: 11,018 (43.04 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 22,038 (86.09 KB)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9888 - loss: 0.0287

# %%
print("Train Loss     : {0:.5f}".format(conv_drop_es_20_hs_adam.history['loss'][-1]))
print("Validation Loss: {0:.5f}".format(conv_drop_es_20_hs_adam.history['val_loss'][-1]))
print("Test Loss      : {0:.5f}".format(conv_drop_es_20_eval_adam[0]))
print("---")
print("Train Accuracy     : {0:.5f}".format(conv_drop_es_20_hs_adam.history['accuracy'][-1]))
print("Validation Accuracy: {0:.5f}".format(conv_drop_es_20_hs_adam.history['val_accuracy'][-1]))
print("Test Accuracy      : {0:.5f}".format(conv_drop_es_20_eval_adam[1]))


# Plot train and validation error per epoch.
plot_history(
    hs={
        'Conv Drop (0.2) ES (20)': conv_drop_es_20_hs_adam
    },
    epochs=epochs,
    metric='loss'
)
plot_history(
    hs={
        'Conv Drop (0.2) ES (20)': conv_drop_es_20_hs_adam
    },
    epochs=epochs,
    metric='accuracy'
)
# Out:
# Train Loss     : 0.03880
# Validation Loss: 0.02591
# Test Loss      : 0.02374
# ---
# Train Accuracy     : 0.98693
# Validation Accuracy: 0.99400
# Test Accuracy      : 0.99150

# %%
exit()
