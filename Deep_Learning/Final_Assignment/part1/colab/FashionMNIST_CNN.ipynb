# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# # Fashion-MNIST — CNN Classification
#
# We compare two architecturally distinct CNNs:
# - **Architecture 1 — Small CNN**: 2 convolutional blocks (8, 16 filters), direct Flatten → Output
# - **Architecture 2 — Deep CNN**: 3 convolutional blocks (32, 64, 128 filters) + dense head (256 units), BatchNorm, Dropout
#
# Each architecture is tested with and without regularisation, and with Early Stopping.

# %% [markdown]
# ### Imports

# %%
import gc
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
# %matplotlib inline

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.layers import (Input, Conv2D, Dense, Dropout,
                                      Flatten, MaxPool2D, BatchNormalization)
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.random import set_seed

print("Tensorflow version " + tf.__version__)
# Out:
# Tensorflow version 2.19.0

# %% [markdown]
# ### Data loading & preprocessing

# %%
batch_size  = 128
classes     = 10
epochs      = 100

class_names = ['T-shirt/top','Trouser','Pullover','Dress','Coat',
               'Sandal','Shirt','Sneaker','Bag','Ankle boot']

(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32') / 255
X_test  = X_test.reshape(X_test.shape[0],   28, 28, 1).astype('float32') / 255
input_shape = (28, 28, 1)

Y_train = to_categorical(y_train, classes)
Y_test  = to_categorical(y_test,  classes)

print(f'Train: {X_train.shape}, Test: {X_test.shape}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Train: (60000, 28, 28, 1), Test: (10000, 28, 28, 1)

# %% [markdown]
# ### Visualise samples

# %%
plt.style.use('dark_background')
fig, axes = plt.subplots(2, 5, figsize=(12, 5))
for i, ax in enumerate(axes.flat):
    ax.imshow(X_train[i].reshape(28, 28), cmap='gray')
    ax.set_title(class_names[y_train[i]], fontsize=9)
    ax.axis('off')
plt.suptitle('Fashion-MNIST — sample images', fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Helper functions

# %%
def plot_history(hs, epochs, metric):
    plt.style.use('dark_background')
    plt.rcParams['figure.figsize'] = [15, 8]
    plt.rcParams['font.size'] = 16
    plt.clf()
    for label, hist in hs.items():
        plt.plot(hist.history[metric],
                 label=f'{label} train {metric}', linewidth=2)
        plt.plot(hist.history[f'val_{metric}'],
                 label=f'{label} val {metric}', linewidth=2)
    x_ticks = np.arange(0, epochs + 1, max(1, epochs // 10))
    x_ticks[0] += 1
    plt.xticks(x_ticks)
    plt.ylim((0, 1))
    plt.xlabel('Epochs')
    plt.ylabel('Loss' if metric == 'loss' else 'Accuracy')
    plt.legend()
    plt.show()


def plot_confusion_matrix(model, title='Confusion Matrix'):
    y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
    cm = confusion_matrix(y_test, y_pred)
    plt.style.use('dark_background')
    fig, ax = plt.subplots(figsize=(10, 8))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    disp.plot(ax=ax, colorbar=True, xticks_rotation=45)
    ax.set_title(title, fontsize=13)
    plt.tight_layout()
    plt.show()


def clean_up(model):
    K.clear_session()
    del model
    gc.collect()

# %% [markdown]
# ---
# ## Architecture 1 — Small CNN
#
# ```
# Input(28,28,1)
#   → Conv2D(8, 3×3, ReLU) → MaxPool(2×2)
#   → Conv2D(16, 3×3, ReLU) → MaxPool(2×2)
#   → Flatten → Output(10, softmax)
# ```
#
# Lightweight model. Two experiments: **no dropout** vs **dropout=0.2**.

# %%
def build_small_cnn(dropout=False):
    np.random.seed(1402)
    set_seed(1981)

    inp = Input(shape=input_shape, name='Input')
    x = Conv2D(8,  (3,3), padding='same', activation='relu', name='Conv2D-1')(inp)
    x = MaxPool2D((2,2), name='MaxPool-1')(x)
    if dropout:
        x = Dropout(0.2, name='Drop-1')(x)
    x = Conv2D(16, (3,3), padding='same', activation='relu', name='Conv2D-2')(x)
    x = MaxPool2D((2,2), name='MaxPool-2')(x)
    if dropout:
        x = Dropout(0.2, name='Drop-2')(x)
    x = Flatten(name='Flatten')(x)
    out = Dense(classes, activation='softmax', name='Output')(x)
    return Model(inputs=inp, outputs=out)


def train(model, optimizer, epochs, batch_size, callbacks=None, verbose=0):
    model.compile(optimizer=optimizer,
                  loss='categorical_crossentropy', metrics=['accuracy'])
    hs = model.fit(X_train, Y_train, validation_split=0.1,
                   epochs=epochs, batch_size=batch_size,
                   callbacks=callbacks, verbose=verbose)
    print('Finished training.')
    print('------------------')
    model.summary()
    return hs

# %% [markdown]
# ### Small CNN — Experiment 1a: No dropout

# %%
small_base = build_small_cnn(dropout=False)
small_base_hs = train(small_base, Adam(), epochs, batch_size)
small_base_eval = small_base.evaluate(X_test, Y_test, verbose=1)

print(f"\nTest Acc: {small_base_eval[1]:.5f}  Test Loss: {small_base_eval[0]:.5f}")
plot_history({'Small CNN (no drop)': small_base_hs}, epochs, 'loss')
plot_history({'Small CNN (no drop)': small_base_hs}, epochs, 'accuracy')

clean_up(small_base)
# Out:
# Finished training.
# ------------------
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Input (InputLayer)              │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv2D-1 (Conv2D)               │ (None, 28, 28, 8)      │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MaxPool-1 (MaxPooling2D)        │ (None, 14, 14, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv2D-2 (Conv2D)               │ (None, 14, 14, 16)     │         1,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MaxPool-2 (MaxPooling2D)        │ (None, 7, 7, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output (Dense)                  │ (None, 10)             │         7,850 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 27,296 (106.63 KB)
#  Trainable params: 9,098 (35.54 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 18,198 (71.09 KB)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8976 - loss: 0.3465
#
# Test Acc: 0.89870  Test Loss: 0.32795

# %% [markdown]
# ### Small CNN — Experiment 1b: Dropout 0.2 + Early Stopping

# %%
es = EarlyStopping(monitor='val_accuracy', patience=10,
                   verbose=1, restore_best_weights=True)

small_reg = build_small_cnn(dropout=True)
small_reg_hs = train(small_reg, Adam(), epochs, batch_size,
                     callbacks=[es], verbose=1)
small_reg_eval = small_reg.evaluate(X_test, Y_test, verbose=1)

ep = len(small_reg_hs.history['loss'])
print(f"\nStopped @ epoch {ep}")
print(f"Test Acc: {small_reg_eval[1]:.5f}  Test Loss: {small_reg_eval[0]:.5f}")
plot_history({'Small CNN (no drop)': small_base_hs,
              'Small CNN (drop+ES)':  small_reg_hs}, epochs, 'loss')
plot_history({'Small CNN (no drop)': small_base_hs,
              'Small CNN (drop+ES)':  small_reg_hs}, epochs, 'accuracy')

clean_up(small_reg)
# Out:
# Epoch 1/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.5768 - loss: 1.1624 - val_accuracy: 0.8127 - val_loss: 0.5092
# Epoch 2/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8088 - loss: 0.5286 - val_accuracy: 0.8482 - val_loss: 0.4317
# Epoch 3/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8318 - loss: 0.4697 - val_accuracy: 0.8588 - val_loss: 0.3976
# Epoch 4/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8460 - loss: 0.4311 - val_accuracy: 0.8647 - val_loss: 0.3807
# Epoch 5/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.
 (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv2D-1 (Conv2D)               │ (None, 28, 28, 8)      │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MaxPool-1 (MaxPooling2D)        │ (None, 14, 14, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Drop-1 (Dropout)                │ (None, 14, 14, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv2D-2 (Conv2D)               │ (None, 14, 14, 16)     │         1,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MaxPool-2 (MaxPooling2D)        │ (None, 7, 7, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Drop-2 (Dropout)                │ (None, 7, 7, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output (Dense)                  │ (None, 10)             │         7,850 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 27,296 (106.63 KB)
#  Trainable params: 9,098 (35.54 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 18,198 (71.09 KB)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9098 - loss: 0.2603
#
# Stopped @ epoch 100
# Test Acc: 0.90790  Test Loss: 0.25868

# %% [markdown]
# ---
# ## Architecture 2 — Deep CNN
#
# ```
# Input(28,28,1)
#   → Conv2D(32, 3×3, ReLU) → BN → MaxPool(2×2) → Dropout(0.2)
#   → Conv2D(64, 3×3, ReLU) → BN → MaxPool(2×2) → Dropout(0.2)
#   → Conv2D(128,3×3, ReLU) → BN → MaxPool(2×2) → Dropout(0.2)
#   → Flatten → Dense(256, ReLU) → Dropout(0.3) → Output(10, softmax)
# ```
#
# Deeper architecture with more filters and a dedicated dense classification head.
# Two experiments: **no regularisation (BN only)** vs **full regularisation (BN + Dropout + ES)**.

# %%
def build_deep_cnn(dropout=False, batchnorm=True):
    np.random.seed(1402)
    set_seed(1981)

    inp = Input(shape=input_shape, name='Input')
    x = inp
    for i, filters in enumerate([32, 64, 128]):
        x = Conv2D(filters, (3,3), padding='same',
                   activation='relu', name=f'Conv2D-{i+1}')(x)
        if batchnorm:
            x = BatchNormalization(name=f'BN-{i+1}')(x)
        x = MaxPool2D((2,2), name=f'MaxPool-{i+1}')(x)
        if dropout:
            x = Dropout(0.2, name=f'Drop-{i+1}')(x)

    x = Flatten(name='Flatten')(x)
    x = Dense(256, activation='relu', name='FC-1')(x)
    if dropout:
        x = Dropout(0.3, name='Drop-FC')(x)
    out = Dense(classes, activation='softmax', name='Output')(x)
    return Model(inputs=inp, outputs=out)

# %% [markdown]
# ### Deep CNN — Experiment 2a: BatchNorm only (no dropout)

# %%
deep_base = build_deep_cnn(dropout=False, batchnorm=True)
deep_base_hs = train(deep_base, Adam(), epochs, batch_size)
deep_base_eval = deep_base.evaluate(X_test, Y_test, verbose=1)

print(f"\nTest Acc: {deep_base_eval[1]:.5f}  Test Loss: {deep_base_eval[0]:.5f}")
plot_history({'Deep CNN (BN only)': deep_base_hs}, epochs, 'loss')
plot_history({'Deep CNN (BN only)': deep_base_hs}, epochs, 'accuracy')

clean_up(deep_base)
# Out:
# Finished training.
# ------------------
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Input (InputLayer)              │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv2D-1 (Conv2D)               │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ BN-1 (BatchNormalization)       │ (None, 28, 28, 32)     │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MaxPool-1 (MaxPooling2D)        │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv2D-2 (Conv2D)               │ (None, 14, 14, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ BN-2 (BatchNormalization)       │ (None, 14, 14, 64)     │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MaxPool-2 (MaxPooling2D)        │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv2D-3 (Conv2D)               │ (None, 7, 7, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ BN-3 (BatchNormalization)       │ (None, 7, 7, 128)      │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MaxPool-3 (MaxPooling2D)        │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Flatten (Flatten)               │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ FC-1 (Dense)                    │ (None, 256)            │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output (Dense)                  │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,173,024 (4.47 MB)
#  Trainable params: 390,858 (1.49 MB)
#  Non-trainable params: 448 (1.75 KB)
#  Optimizer params: 781,718 (2.98 MB)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9128 - loss: 0.9567
#
# Test Acc: 0.91670  Test Loss: 0.92524

# %% [markdown]
# ### Deep CNN — Experiment 2b: BatchNorm + Dropout + Early Stopping

# %%
es = EarlyStopping(monitor='val_accuracy', patience=10,
                   verbose=1, restore_best_weights=True)

deep_reg = build_deep_cnn(dropout=True, batchnorm=True)
deep_reg_hs = train(deep_reg, Adam(), epochs, batch_size,
                    callbacks=[es], verbose=1)
deep_reg_eval = deep_reg.evaluate(X_test, Y_test, verbose=1)

ep = len(deep_reg_hs.history['loss'])
print(f"\nStopped @ epoch {ep}")
print(f"Test Acc: {deep_reg_eval[1]:.5f}  Test Loss: {deep_reg_eval[0]:.5f}")
plot_history({'Deep CNN (BN only)':       deep_base_hs,
              'Deep CNN (BN+Drop+ES)':    deep_reg_hs}, epochs, 'loss')
plot_history({'Deep CNN (BN only)':       deep_base_hs,
              'Deep CNN (BN+Drop+ES)':    deep_reg_hs}, epochs, 'accuracy')
# Out:
# Epoch 1/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 17s 23ms/step - accuracy: 0.7222 - loss: 0.8632 - val_accuracy: 0.5950 - val_loss: 1.8029
# Epoch 2/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8627 - loss: 0.3726 - val_accuracy: 0.8918 - val_loss: 0.2959
# Epoch 3/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8846 - loss: 0.3118 - val_accuracy: 0.8978 - val_loss: 0.2826
# Epoch 4/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8971 - loss: 0.2824 - val_accuracy: 0.8998 - val_loss: 0.2677
# Epoch 5/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9045 - loss: 0.2608 - val_accuracy: 0.8977 - val_loss: 0.2821
# Epoch 6/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9092 - loss: 0.2446 - val_accuracy: 0.9132 - val_loss: 0.2457
# Epoch 7/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9144 - loss: 0.2261 - val_accuracy: 0.9082 - val_loss: 0.2538
# Epoch 8/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9183 - loss: 0.2212 - val_accuracy: 0.9130 - val_loss: 0.2487
# Epoch 9/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9210 - loss: 0.2123 - val_accuracy: 0.9167 - val_loss: 0.2381
# Epoch 10/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9239 - loss: 0.1995 - val_accuracy: 0.9205 - val_loss: 0.2336
# Epoch 11/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9290 - loss: 0.1956 - val_accuracy: 0.9113 - val_loss: 0.2513
# Epoch 12/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9279 - loss: 0.1886 - val_accuracy: 0.9140 - val_loss: 0.2476
# Epoch 13/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9280 - loss: 0.1893 - val_accuracy: 0.9193 - val_loss: 0.2369
# Epoch 14/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9323 - loss: 0.1822 - val_accuracy: 0.9227 - val_loss: 0.2213
# Epoch 15/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9362 - loss: 0.1686 - val_accuracy: 0.9185 - val_loss: 0.2390
# Epoch 16/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9371 - loss: 0.1700 - val_accuracy: 0.9190 - val_loss: 0.2390
# Epoch 17/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9379 - loss: 0.1632 - val_accuracy: 0.9210 - val_loss: 0.2385
# Epoch 18/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9395 - loss: 0.1601 - val_accuracy: 0.9242 - val_loss: 0.2257
# Epoch 19/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9419 - loss: 0.1549 - val_accuracy: 0.9287 - val_loss: 0.2169
# Epoch 20/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9431 - loss: 0.1515 - val_accuracy: 0.9325 - val_loss: 0.2096
# Epoch 21/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9448 - loss: 0.1491 - val_accuracy: 0.9318 - val_loss: 0.2080
# Epoch 22/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9449 - loss: 0.1435 - val_accuracy: 0.9252 - val_loss: 0.2257
# Epoch 23/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9466 - loss: 0.1426 - val_accuracy: 0.9297 - val_loss: 0.2235
# Epoch 24/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9492 - loss: 0.1384 - val_accuracy: 0.9295 - val_loss: 0.2461
# Epoch 25/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9476 - loss: 0.1360 - val_accuracy: 0.9113 - val_loss: 0.2814
# Epoch 26/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9486 - loss: 0.1318 - val_accuracy: 0.9262 - val_loss: 0.2330
# Epoch 27/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9499 - loss: 0.1294 - val_accuracy: 0.9283 - val_loss: 0.2396
# Epoch 28/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9531 - loss: 0.1272 - val_accuracy: 0.9325 - val_loss: 0.2309
# Epoch 29/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9513 - loss: 0.1285 - val_accuracy: 0.9297 - val_loss: 0.2337
# Epoch 30/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9542 - loss: 0.1220 - val_accuracy: 0.9288 - val_loss: 0.2371
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 20.
# Finished training.
# ------------------
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Input (InputLayer)              │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv2D-1 (Conv2D)               │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ BN-1 (BatchNormalization)       │ (None, 28, 28, 32)     │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MaxPool-1 (MaxPooling2D)        │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Drop-1 (Dropout)                │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv2D-2 (Conv2D)               │ (None, 14, 14, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ BN-2 (BatchNormalization)       │ (None, 14, 14, 64)     │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MaxPool-2 (MaxPooling2D)        │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Drop-2 (Dropout)                │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv2D-3 (Conv2D)               │ (None, 7, 7, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ BN-3 (BatchNormalization)       │ (None, 7, 7, 128)      │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MaxPool-3 (MaxPooling2D)        │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Drop-3 (Dropout)                │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Flatten (Flatten)               │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ FC-1 (Dense)                    │ (None, 256)            │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Drop-FC (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output (Dense)                  │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,173,024 (4.47 MB)
#  Trainable params: 390,858 (1.49 MB)
#  Non-trainable params: 448 (1.75 KB)
#  Optimizer params: 781,718 (2.98 MB)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9246 - loss: 0.2360
#
# Stopped @ epoch 30
# Test Acc: 0.92570  Test Loss: 0.23455

# %% [markdown]
# ### Confusion matrix — best model (Deep CNN regularised)

# %%
plot_confusion_matrix(deep_reg, title='Confusion Matrix — Deep CNN (BN + Dropout + ES)')
clean_up(deep_reg)

# %% [markdown]
# ---
# ## Final comparison — all CNN experiments

# %%
print(f"{'Model':<40} {'Test Acc':>10} {'Test Loss':>12}")
print('-' * 64)
rows = [
    ('Small CNN (no dropout)',           small_base_eval),
    ('Small CNN (Dropout 0.2 + ES)',     small_reg_eval),
    ('Deep CNN  (BN only)',              deep_base_eval),
    ('Deep CNN  (BN + Dropout + ES)',    deep_reg_eval),
]
for name, ev in rows:
    print(f"{name:<40} {ev[1]:>10.5f} {ev[0]:>12.5f}")
# Out:
# Model                                      Test Acc    Test Loss
# ----------------------------------------------------------------
# Small CNN (no dropout)                      0.89870      0.32795
# Small CNN (Dropout 0.2 + ES)                0.90790      0.25868
# Deep CNN  (BN only)                         0.91670      0.92524
# Deep CNN  (BN + Dropout + ES)               0.92570      0.23455
